# %%
print("Prajwwal fslfjasfaijfas")
# Out:
# Prajwwal fslfjasfaijfas

# %%
print('Eplorartory Data Analysis')
# Out:
# Eplorartory Data Analysis

# %%
# Data Source 
URL : https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/automobileEDA.csv

# %%
#Importing the libraries
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# Get the data
 # This dataset was hosted on IBM Cloud

# %%
path='https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/automobileEDA.csv'
df = pd.read_csv(path)
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'aspiration', 'num-of-doors',
#        'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length',
#        'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders',
#        'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio',
#        'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price',
#        'city-L/100km', 'horsepower-binned', 'diesel', 'gas'],
#       dtype='object')

# %%
df.describe().transpose()
# Out:
#                    count          mean          std          min          25%  \
# symboling          201.0      0.840796     1.254802    -2.000000     0.000000
# normalized-losses  201.0    122.000000    31.996250    65.000000   101.000000
# wheel-base         201.0     98.797015     6.066366    86.600000    94.500000
# length             201.0      0.837102     0.059213     0.678039     0.801538
# width              201.0      0.915126     0.029187     0.837500     0.890278
# height             201.0     53.766667     2.447822    47.800000    52.000000
# curb-weight        201.0   2555.666667   517.296727  1488.000000  2169.000000
# engine-size        201.0    126.875622    41.546834    61.000000    98.000000
# bore               201.0      3.330692     0.268072     2.540000     3.150000
# stroke             197.0      3.256904     0.319256     2.070000     3.110000
# compression-ratio  201.0     10.164279     4.004965     7.000000     8.600000
# ...

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# city-L/100km         float64
# horsepower-binned     object
# diesel                 int64
# gas                    int64
# dtype: object

# %%
df.isnull().any()
# Out:
# symboling            False
# normalized-losses    False
# make                 False
# aspiration           False
# num-of-doors         False
# body-style           False
# drive-wheels         False
# engine-location      False
# wheel-base           False
# length               False
# width                False
# height               False
# curb-weight          False
# engine-type          False
# num-of-cylinders     False
# engine-size          False
# fuel-system          False
# bore                 False
# stroke                True
# compression-ratio    False
# horsepower           False
# peak-rpm             False
# city-mpg             False
# highway-mpg          False
# price                False
# city-L/100km         False
# horsepower-binned     True
# diesel               False
# gas                  False
# dtype: bool

# %%
df['stroke'].value_counts()
# Out:
# 3.40    19
# 3.03    14
# 3.15    14
# 3.23    14
# 3.39    13
# 2.64    11
# 3.35     9
# 3.29     9
# 3.46     8
# 3.41     6
# 3.19     6
# 3.07     6
# 3.58     6
# 3.27     6
# 3.50     6
# 3.64     5
# 3.52     5
# 3.47     4
# 3.86     4
# 3.54     4
# 3.90     3
# 2.90     3
# 3.11     3
# 3.08     2
# 2.19     2
# 2.80     2
# 3.10     2
# 4.17     2
# 2.68     2
# 2.87     1
# 3.21     1
# 3.16     1
# 3.12     1
# 2.76     1
# 2.07     1
# 2.36     1
# Name: stroke, dtype: int64

# %%
df['stroke'].isnull().sum()
# Out:
# 4

# %%
df['stroke'].dtype
# Out:
# dtype('float64')

# %%
df['stroke'] = df['stroke'].fillna(df['stroke'].mean())

# %%
df['stroke'].isnull().sum()
# Out:
# 0

# %%
df['horsepower-binned'].value_counts()
# Out:
# Low       115
# Medium     62
# High       23
# Name: horsepower-binned, dtype: int64

# %%
df['horsepower-binned'].isnull().sum()
# Out:
# 1

# %%
df['horsepower-binned'].fillna('Low',inplace =True)

# %%
df['horsepower-binned'].isnull().any()
# Out:
# False

# %%
df.isnull().any()
# Out:
# symboling            False
# normalized-losses    False
# make                 False
# aspiration           False
# num-of-doors         False
# body-style           False
# drive-wheels         False
# engine-location      False
# wheel-base           False
# length               False
# width                False
# height               False
# curb-weight          False
# engine-type          False
# num-of-cylinders     False
# engine-size          False
# fuel-system          False
# bore                 False
# stroke               False
# compression-ratio    False
# horsepower           False
# peak-rpm             False
# city-mpg             False
# highway-mpg          False
# price                False
# city-L/100km         False
# horsepower-binned    False
# diesel               False
# gas                  False
# dtype: bool

# %%
import seaborn as sns

# %%
#sns.boxplot(data = df, x='', y = '')

# %%
df.corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.007992           0.055127    0.157964  0.123913
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075819           0.217299    0.371147  0.579821
# ...

# %%
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %%
df.isnull().any()
# Out:
# symboling            False
# normalized-losses    False
# make                 False
# aspiration           False
# num-of-doors         False
# body-style           False
# drive-wheels         False
# engine-location      False
# wheel-base           False
# length               False
# width                False
# height               False
# curb-weight          False
# engine-type          False
# num-of-cylinders     False
# engine-size          False
# fuel-system          False
# bore                 False
# stroke               False
# compression-ratio    False
# horsepower           False
# peak-rpm             False
# city-mpg             False
# highway-mpg          False
# price                False
# city-L/100km         False
# horsepower-binned    False
# diesel               False
# gas                  False
# dtype: bool

# %%
import seaborn as sns

# %%
sns.boxplot(x = 'horsepower-binned' ,y = 'price', data = df)

# %%
x = df['engine-size']
y = df['price']


plt.xlabel('Engine-size')
plt.ylabel('Price')
plt.scatter(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
#  For viualization of any columns you need to  consider its dtype of that column.
#  According to  the datatype of column , you decide which plotting to be done

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# city-L/100km         float64
# horsepower-binned     object
# diesel                 int64
# gas                    int64
# dtype: object

# %%
df['peak-rpm'].dtype
# Out:
# dtype('float64')

# %%
df[['bore','stroke','compression-ratio', 'horsepower']].corr()
# Out:
#                        bore    stroke  compression-ratio  horsepower
# bore               1.000000 -0.055390           0.001263    0.566936
# stroke            -0.055390  1.000000           0.187854    0.098282
# compression-ratio  0.001263  0.187854           1.000000   -0.214514
# horsepower         0.566936  0.098282          -0.214514    1.000000

# %%
sns.regplot(x = 'gas',y = 'price', data = df)

# %%
sns.regplot(x = 'engine-size', y= 'price', data =df)

# %%
df.corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.007992           0.055127    0.157964  0.123913
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075819           0.217299    0.371147  0.579821
# ...

# %%
df[['horsepower', 'price']].corr()
# Out:
#             horsepower     price
# horsepower    1.000000  0.809575
# price         0.809575  1.000000

# %%
sns.regplot(x = 'horsepower', y = 'price', data =df)

# %%
df[['length', 'width']].corr()
# Out:
#          length    width
# length  1.00000  0.85717
# width   0.85717  1.00000

# %%
sns.regplot(x = 'length', y = 'width', data =df)

# %%
df[['highway-mpg', 'price']].corr()
# Out:
#              highway-mpg     price
# highway-mpg     1.000000 -0.704692
# price          -0.704692  1.000000

# %%
sns.regplot(x = 'highway-mpg', y = 'price', data =df)

# %%
df[['peak-rpm', 'price']].corr()
# Out:
#           peak-rpm     price
# peak-rpm  1.000000 -0.101616
# price    -0.101616  1.000000

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# city-L/100km         float64
# horsepower-binned     object
# diesel                 int64
# gas                    int64
# dtype: object

# %%
df['engine-location'].value_counts()
# Out:
# front    198
# rear       3
# Name: engine-location, dtype: int64

# %%
df['body-style'].value_counts()
# Out:
# sedan          94
# hatchback      68
# wagon          25
# hardtop         8
# convertible     6
# Name: body-style, dtype: int64

# %%
sns.boxplot(x = 'body-style', y = 'price', data =df)

# %%
df.boxplot(column = 'price')

# %%
sns.boxplot(x = 'engine-location', y = 'price', data =df)

# %%
df['drive-wheels'].value_counts()
# Out:
# fwd    118
# rwd     75
# 4wd      8
# Name: drive-wheels, dtype: int64

# %%
d = df['drive-wheels'].value_counts().to_frame()
d.rename(columns={'drive-wheels':'value_counts'},inplace =True)
d
# Out:
#      value_counts
# fwd           118
# rwd            75
# 4wd             8

# %%
d = df[['engine-size', 'price']].groupby('engine-size').mean()

# %%
d
# Out:
#                     price
# engine-size
# 61            5151.000000
# 70           12145.000000
# 79            5399.000000
# 80           15645.000000
# 90            6384.200000
# 91            6435.000000
# 92            6773.133333
# 97            7815.642857
# 98            8170.857143
# 103           7099.000000
# 108          10056.307692
# 109          10309.375000
# 110           9526.750000
# 111           6785.000000
# 119          11048.000000
# 120          13106.142857
# 121          15223.333333
# 122           9521.400000
# 130          16841.250000
# 131          23875.000000
# 132           9595.000000
# 134          18247.000000
# 136          16525.000000
# 140          17391.500000
# 141          16767.142857
# 145          22470.000000
# 146          11415.666667
# 151          22018.000000
# 152          15914.166667
# 156          13543.000000
# 161          15750.000000
# 164          22213.333333
# 171          16082.000000
# 173          21485.000000
# ...

# %%
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %%
df[['drive-wheels', 'price']].groupby('drive-wheels').mean()
# Out:
#                      price
# drive-wheels
# 4wd           10241.000000
# fwd            9244.779661
# rwd           19757.613333

# %%
df[['drive-wheels', 'price']].groupby('drive-wheels').count()
# Out:
#               price
# drive-wheels
# 4wd               8
# fwd             118
# rwd              75

# %%
df[['engine-location', 'price']].groupby('engine-location').count()
# Out:
#                  price
# engine-location
# front              198
# rear                 3

# %%
df[['engine-location', 'price']].groupby('engine-location').mean()
# Out:
#                         price
# engine-location
# front            12884.085859
# rear             34528.000000

# %%
df[['engine-location', 'length']].groupby('engine-location').mean()
# Out:
#                    length
# engine-location
# front            0.837488
# rear             0.811629

# %%
df['length'].mean()
# Out:
# 0.8371023307298195

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'aspiration', 'num-of-doors',
#        'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length',
#        'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders',
#        'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio',
#        'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price',
#        'city-L/100km', 'horsepower-binned', 'diesel', 'gas'],
#       dtype='object')

# %%
df[['horsepower-binned','price','length']].head()
# Out:
#   horsepower-binned    price    length
# 0            Medium  13495.0  0.811148
# 1            Medium  16500.0  0.811148
# 2            Medium  16500.0  0.822681
# 3            Medium  13950.0  0.848630
# 4            Medium  17450.0  0.848630

# %%
df[['horsepower-binned','price','length']].groupby('horsepower-binned').mean()
# Out:
#                           price    length
# horsepower-binned
# High               25899.130435  0.892861
# Low                 9244.362069  0.813066
# Medium             15913.016129  0.861388

# %%
df_group_one = df[['drive-wheels','body-style','price']].groupby('drive-wheels').count()

# %%
df_group_one
# Out:
#               body-style  price
# drive-wheels
# 4wd                    8      8
# fwd                  118    118
# rwd                   75     75

# %%
d =df[['drive-wheels','body-style','price']].groupby(['drive-wheels', 'body-style'], as_index= False).mean()

# %%
d
# Out:
#    drive-wheels   body-style         price
# 0           4wd    hatchback   7603.000000
# 1           4wd        sedan  12647.333333
# 2           4wd        wagon   9095.750000
# 3           fwd  convertible  11595.000000
# 4           fwd      hardtop   8249.000000
# 5           fwd    hatchback   8396.387755
# 6           fwd        sedan   9811.800000
# 7           fwd        wagon   9997.333333
# 8           rwd  convertible  23949.600000
# 9           rwd      hardtop  24202.714286
# 10          rwd    hatchback  14337.777778
# 11          rwd        sedan  21711.833333
# 12          rwd        wagon  16994.222222

# %%
df[['body-style','price']].groupby('body-style').mean()
# Out:
#                     price
# body-style
# convertible  21890.500000
# hardtop      22208.500000
# hatchback     9957.441176
# sedan        14459.755319
# wagon        12371.960000

# %%
from scipy import stats

# %%
Pearson , p_value = stats.pearsonr(df['engine-size'], df['price'])

# %%
Pearson
# Out:
# 0.8723351674455185

# %%
p_value
# Out:
# 9.265491622198389e-64

# %%
grouped=df[['drive-wheels', 'price']].groupby(['drive-wheels'])
grouped.head(2)
# Out:
#     drive-wheels    price
# 0            rwd  13495.0
# 1            rwd  16500.0
# 3            fwd  13950.0
# 4            4wd  17450.0
# 5            fwd  15250.0
# 136          4wd   7603.0

# %%
grouped.get_group('4wd')['price']
# Out:
# 4      17450.0
# 136     7603.0
# 140     9233.0
# 141    11259.0
# 144     8013.0
# 145    11694.0
# 150     7898.0
# 151     8778.0
# Name: price, dtype: float64

# %%
# ANOVA
f_val, p_val = stats.f_oneway(grouped.get_group('fwd')['price'], grouped.get_group('rwd')['price'], grouped.get_group('4wd')['price'])  
 
print( "ANOVA results: F=", f_val, ", P =", p_val)
# Out:
# ANOVA results: F= 67.95406500780399 , P = 3.3945443577151245e-23
